# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 교차검증
# 모델을 평가하는 방법 중 하나
#
# ### K-Fold 교차검증
# 데이터를 K개로 쪼갠다.
# 하나는 테스트 데이터 나머지는 훈련 데이터로 만들어서 성능을 구한다.
# 이를 K번 반복.
#
# 그 후 K번의 성능의 평균을 구한다.
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
#
# ## Precision (정밀도)
# -> a / a + c
#
# ## 재현율
# -> a / a + b
#
# ## Accuracy (정확도)
# -> a + d / a + b + c + d
#
# ## F1 Score (정밀도와 재현율의 조화 평균)
# -> 2 * (정밀도 * 재현율) / (정밀도 + 재현율)
